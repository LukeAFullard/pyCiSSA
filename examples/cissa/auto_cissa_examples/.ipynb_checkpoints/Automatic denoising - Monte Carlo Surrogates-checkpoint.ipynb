# %% [markdown]
# # This notebook contains an example of denoising a signal using Cissa. There are multiple methods to do this in pyCissa, but this notebook deals with the Monte-Carlo surrogate approach.

# %%
#importing required packages
import pandas as pd
import os
dir_path = os.path.abspath('')
os.chdir('../../..')
home_path = os.path.abspath('')
os.chdir('./pycissa/processing/cissa')
from cissa import Cissa
os.chdir(home_path)

# %%
## Read data file  (source is the Ministry of Economy of Spain.)
data = pd.read_excel(home_path + r'/data/EPC.xlsx',sheet_name = 'Data')

# %%
#create the cissa object
cissa_object = Cissa(t=data['Date'],x=data['Electric power consumption in Spain'])

# %% [markdown]
# ## 1. Monte-Carlo surrogate method to denoise

# %%
#Run auto denoise with L = 96 (8 years), grouping_type = 'monte_carlo' (the default), alpha = 0.05 (95%), K_surrogates = 5 (which means 5/alpha - 1 = 99 surrogates)
#surrogates = 'random_permutation'
cissa_object.auto_denoise(L=96, K_surrogates = 5, alpha = 0.05)

# %%
#plot the denoised result
cissa_object.figures.get('cissa').get('figure_denoised')

# %%
#plot the significant components (blue dots) which are above the line of significance (red dashed line)
#NOTE: x-axis is frequency in units of per timestep - for monthly data then 0.08333 = 1 year
cissa_object.figures.get('cissa').get('figure_monte_carlo')

# %%
'''Aside from the trend, there are three significant components in blue above. We can find these in the cissa results dictionary'''
# Out:
# 'Aside from the trend, there are three significant components in blue above. We can find these in the cissa results dictionary'

# %%
cissa_object.results.get('cissa').keys()
# Out:
# dict_keys(['components', 'model parameters', 'noise component tests', 'fractal scaling results'])

# %%
#here we iterate through the results and find the frequencies that passed monte-carlo test.
#Note the result dictionary is structured according to input options.
#We also convert the frequency to period in years since we have monthly data
print("Trend is included in significant components.")
print(" ")
for key_j in cissa_object.results.get('cissa').get('components').keys():
    if key_j != 'trend':
        if cissa_object.results.get('cissa').get('components').get(key_j).get('monte_carlo').get('random_permutation').get('alpha').get(0.05).get('pass'):
            print("Significant CiSSA component found!")
            print(f" Frequency = {key_j} per unit timestep")
            print(f"Period = {12*key_j} years")
            print(" ")
# Out:
# Trend is included in significant components.
#
# Significant CiSSA component found!
#  Frequency = 0.08333333333333333 per unit timestep
# Period = 1.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.16666666666666666 per unit timestep
# Period = 2.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.3333333333333333 per unit timestep
# Period = 4.0 years

# %%
"So trend, 1, 2, and 4 year components were found to be significant."
# Out:
# 'So trend, 1, 2, and 4 year components were found to be significant.'

# %%
"We can also plot figures of each components and also the residuals/noise"
# Out:
# 'We can also plot figures of each components and also the residuals/noise'

# %%
cissa_object.figures.get('cissa').get('figure_split_components')

# %%
cissa_object.figures.get('cissa').get('figure_residual_check')

# %% [markdown]
# ## We can get the proportion of the PSD (Power spectral density) for the trend, periodic, and noise components...

# %%
print('''COMPONENT VARIANCE''')
print(f'''TREND   : {cissa_object.results.get('cissa').get('noise component tests').get('trend_share')}%''')
print(f'''PERIODIC: {cissa_object.results.get('cissa').get('noise component tests').get('periodic_share')}%''')
print(f'''NOISE   : {cissa_object.results.get('cissa').get('noise component tests').get('noise_share')}%''')
# Out:
# COMPONENT VARIANCE
# TREND   : 89.46614410358026%
# PERIODIC: 2.0991828999283495%
# NOISE   : 8.177911791778104%

# %% [markdown]
# ### For this time series and this noise identification method, the trend accounts for almost 90% of the variance, while only 2% is from periodic terms.

# %% [markdown]
# # 2. We can try an alternative surrogate generation method.
# # Since the series is trending the small shuffle surrogate mthod may be more appropriate:
# # Nakamura, T., & Small, M. (2005). Small-shuffle surrogate data: Testing for dynamics in fluctuating data with trends. Physical Review E, 72(5), 056216.

# %%
#2. We can try an alternative surrogate generation method. 
#Since the series is trending the small shuffle surrogate mthod may be more appropriate:  
# Nakamura, T., & Small, M. (2005). Small-shuffle surrogate data: Testing for dynamics in fluctuating data with trends. Physical Review E, 72(5), 056216.
cissa_object.auto_denoise(L=96, K_surrogates = 5, alpha = 0.05, surrogates = 'small_shuffle')

# %%
#plot the significant components (blue dots) which are above the line of significance (red dashed line)
#NOTE: x-axis is frequency in units of per timestep - for monthly data then 0.08333 = 1 year
cissa_object.figures.get('cissa').get('figure_monte_carlo')

# %%
#here we iterate through the results and find the frequencies that passed monte-carlo test.
#Note the result dictionary is structured according to input options.
#We also convert the frequency to period in years since we have monthly data
for key_j in cissa_object.results.get('cissa').get('components').keys():
    if key_j != 'trend':
        if cissa_object.results.get('cissa').get('components').get(key_j).get('monte_carlo').get('small_shuffle').get('alpha').get(0.05).get('pass'):
            print("Significant CiSSA component found!")
            print(f" Frequency = {key_j} per unit timestep")
            print(f"Period = {12*key_j} years")
            print(" ")
    else:
        print(f"Trend significant: {cissa_object.results.get('cissa').get('components').get(key_j).get('monte_carlo').get('small_shuffle').get('alpha').get(0.05).get('pass')}")
# Out:
# Significant CiSSA component found!
#  Frequency = 0.08333333333333333 per unit timestep
# Period = 1.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.16666666666666666 per unit timestep
# Period = 2.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.3333333333333333 per unit timestep
# Period = 4.0 years
#
# Trend significant: True

# %% [markdown]
# # 3. Can also try using autoregressive order 1 surrogates

# %%
#3. Can also try using autoregressive order 1 surrogates
cissa_object.auto_denoise(L=96, K_surrogates = 5, alpha = 0.05, surrogates = 'ar1_fit')

# %%
#plot the significant components (blue dots) which are above the line of significance (red dashed line)
#NOTE: x-axis is frequency in units of per timestep - for monthly data then 0.08333 = 1 year
cissa_object.figures.get('cissa').get('figure_monte_carlo')

# %%
#here we iterate through the results and find the frequencies that passed monte-carlo test.
#Note the result dictionary is structured according to input options.
#We also convert the frequency to period in years since we have monthly data
print("Trend is included in significant components.")
print(" ")
for key_j in cissa_object.results.get('cissa').get('components').keys():
    if key_j != 'trend':
        if cissa_object.results.get('cissa').get('components').get(key_j).get('monte_carlo').get('ar1_fit').get('alpha').get(0.05).get('pass'):
            print("Significant CiSSA component found!")
            print(f" Frequency = {key_j} per unit timestep")
            print(f"Period = {12*key_j} years")
            print(" ")
# Out:
# Trend is included in significant components.
#
# Significant CiSSA component found!
#  Frequency = 0.08333333333333333 per unit timestep
# Period = 1.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.16666666666666666 per unit timestep
# Period = 2.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.3333333333333333 per unit timestep
# Period = 4.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.4166666666666667 per unit timestep
# Period = 5.0 years

# %% [markdown]
# # 4. We can also ask pyCiSSA to fit a colored noise spectrum to the data and use surrogates with a similar color noise spectrum:

# %%
#with a segmented slope fit (two noise colours)

# %%
cissa_object.auto_denoise(L=96, K_surrogates = 5, alpha = 0.05, surrogates = 'coloured_noise_segmented')
# Out:
#                  Breakpoint Model Comparision Results
# ====================================================================================================
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -92.463         True        5.579
# 1                    -86.469         True       5.3801
#
# Min BIC (Bayesian Information Criterion) suggests best model

# %%
#plot the significant components (blue dots) which are above the line of significance (red dashed line)
#NOTE: x-axis is frequency in units of per timestep - for monthly data then 0.08333 = 1 year
cissa_object.figures.get('cissa').get('figure_monte_carlo')

# %%
#here we iterate through the results and find the frequencies that passed monte-carlo test.
#Note the result dictionary is structured according to input options.
#We also convert the frequency to period in years since we have monthly data
print("Trend is included in significant components.")
print(" ")
for key_j in cissa_object.results.get('cissa').get('components').keys():
    if key_j != 'trend':
        if cissa_object.results.get('cissa').get('components').get(key_j).get('monte_carlo').get('coloured_noise_segmented').get('alpha').get(0.05).get('pass'):
            print("Significant CiSSA component found!")
            print(f" Frequency = {key_j} per unit timestep")
            print(f"Period = {12*key_j} years")
            print(" ")
# Out:
# Trend is included in significant components.
#
# Significant CiSSA component found!
#  Frequency = 0.010416666666666666 per unit timestep
# Period = 0.125 years
#
# Significant CiSSA component found!
#  Frequency = 0.020833333333333332 per unit timestep
# Period = 0.25 years
#
# Significant CiSSA component found!
#  Frequency = 0.03125 per unit timestep
# Period = 0.375 years
#
# Significant CiSSA component found!
#  Frequency = 0.0625 per unit timestep
# Period = 0.75 years
#
# Significant CiSSA component found!
#  Frequency = 0.07291666666666667 per unit timestep
# Period = 0.875 years
#
# Significant CiSSA component found!
#  Frequency = 0.08333333333333333 per unit timestep
# Period = 1.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.16666666666666666 per unit timestep
# Period = 2.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.3333333333333333 per unit timestep
# Period = 4.0 years

# %% [markdown]
# ## Modelling the surrogates against a segmented coloured noise hypothesis results in many more significant components (more assigned to periodic, less to noise)

# %%
cissa_object.figures.get('cissa').get('figure_split_components')

# %% [markdown]
# ## Perhaps the trend is swamping the surrogate method. Let's remove the trend and test again.

# %%
#Run auto detrend with L = 96 (8 years)
cissa_object.auto_detrend(L=96)

# %%
#Run auto denoise with L = 96 (8 years), grouping_type = 'monte_carlo' (the default), alpha = 0.05 (95%), K_surrogates = 5 (which means 5/alpha - 1 = 99 surrogates)
#surrogates = 'random_permutation'
cissa_object_detrended=Cissa(t=data['Date'],x=cissa_object.x_detrended)

# %%
#Run auto denoise with L = 96 (8 years), grouping_type = 'monte_carlo' (the default), alpha = 0.05 (95%), K_surrogates = 5 (which means 5/alpha - 1 = 99 surrogates)
#surrogates = 'random_permutation'
cissa_object_detrended.auto_denoise(L=96, K_surrogates = 5, alpha = 0.05)

# %%
#plot the significant components (blue dots) which are above the line of significance (red dashed line)
#NOTE: x-axis is frequency in units of per timestep - for monthly data then 0.08333 = 1 year
cissa_object_detrended.figures.get('cissa').get('figure_monte_carlo')

# %%
#here we iterate through the results and find the frequencies that passed monte-carlo test.
#Note the result dictionary is structured according to input options.
#We also convert the frequency to period in years since we have monthly data
print("Trend is included in significant components.")
print(" ")
for key_j in cissa_object_detrended.results.get('cissa').get('components').keys():
    if key_j != 'trend':
        if cissa_object_detrended.results.get('cissa').get('components').get(key_j).get('monte_carlo').get('random_permutation').get('alpha').get(0.05).get('pass'):
            print("Significant CiSSA component found!")
            print(f" Frequency = {key_j} per unit timestep")
            print(f"Period = {12*key_j} years")
            print(" ")
# Out:
# Trend is included in significant components.
#
# Significant CiSSA component found!
#  Frequency = 0.010416666666666666 per unit timestep
# Period = 0.125 years
#
# Significant CiSSA component found!
#  Frequency = 0.08333333333333333 per unit timestep
# Period = 1.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.16666666666666666 per unit timestep
# Period = 2.0 years
#
# Significant CiSSA component found!
#  Frequency = 0.3333333333333333 per unit timestep
# Period = 4.0 years

# %%
cissa_object_detrended.figures.get('cissa').get('figure_split_components')

# %%
cissa_object_detrended.figures.get('cissa').get('figure_residual_check')

# %% [markdown]
# ## It can sometimes be advantageous to remove the trend then apply cissa to the detrended data
