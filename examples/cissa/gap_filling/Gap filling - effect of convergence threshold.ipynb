# %% [markdown]
# # Gap filling - when is my algorithm converged?

# %%
#importing required packages
import pandas as pd
import numpy as np
import copy
import os
import warnings
warnings.filterwarnings('ignore')
os.chdir('../../..')
home_path = os.path.abspath('')
from pycissa import Cissa

# %%
## Read data file  (source is the Ministry of Economy of Spain.)
data = pd.read_excel(home_path + r'/data/EPC.xlsx',sheet_name = 'Data')

# %%
data_with_gaps = copy.deepcopy(data)
data_with_gaps['Electric power consumption in Spain'][100] = np.nan
data_with_gaps['Electric power consumption in Spain'][200] = np.nan
data_with_gaps['Electric power consumption in Spain'][300] = np.nan
data_with_gaps['Electric power consumption in Spain'][400] = np.nan
data_with_gaps['Electric power consumption in Spain'][500] = np.nan
print(data_with_gaps['Electric power consumption in Spain'][499:502])
# Out:
# 499    21425.56417
# 500            NaN
# 501    19817.63946
# Name: Electric power consumption in Spain, dtype: float64

# %% [markdown]
# ## convergence = 1000

# %%
#create the cissa object
cissa_object_1000 = Cissa(t=data_with_gaps['Date'],x=data_with_gaps['Electric power consumption in Spain'])
cissa_object_1000.auto_cissa(L = 12*23,
                       K_surrogates = 5, alpha = 0.05,  #settings some parameters for the Monte-Carlo routine
                       test_number = 20, test_repeats=20, #These settings help us to understand the error during gap filling. For 10 repeats we remove 10 known points, gap fill, and calculate the error. On the last run all points are included (none removed) 
                       initial_guess = ['previous', 1.1], #this means we set missing values to the previous good value multiplied by 1.25 
                        max_iter = 1000, #ensuring we have enough iterations to converge
                        convergence = ['value', 1000], #convergence value    
                        verbose = False    
                       )
cissa_object_1000.figures.get('cissa').get('figure_gap_fill_error')
# Out:
# Checking for censored or nan data...
# RUNNING CISSA!
# Performing monte-carlo significance analysis...
# Grouping components...
# Running frequency time analysis...
# Analysing trend...
# Calculating time-series autocorrelation...
# running peridogram analysis
#
#                  Breakpoint Model Comparision Results
# ...
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -398.57         True       5.6224
# 1                    -410.75         True       4.7502
#
# Min BIC (Bayesian Information Criterion) suggests best model
# Auto Cissa Complete!

# %%
cissa_object_1000.figures.get('cissa').get('figure_gap_fill')

# %% [markdown]
# ## convergence = 500

# %%
#create the cissa object
cissa_object_500 = Cissa(t=data_with_gaps['Date'],x=data_with_gaps['Electric power consumption in Spain'])
cissa_object_500.auto_cissa(L = 12*23,
                       K_surrogates = 5, alpha = 0.05,  #settings some parameters for the Monte-Carlo routine
                       test_number = 20, test_repeats=20, #These settings help us to understand the error during gap filling. For 10 repeats we remove 10 known points, gap fill, and calculate the error. On the last run all points are included (none removed) 
                       initial_guess = ['previous', 1.1], #this means we set missing values to the previous good value multiplied by 1.25 
                        max_iter = 1000, #ensuring we have enough iterations to converge
                        convergence = ['value', 500], #convergence value    
                        verbose = False    
                       )
cissa_object_500.figures.get('cissa').get('figure_gap_fill_error')
# Out:
# Checking for censored or nan data...
# RUNNING CISSA!
# Performing monte-carlo significance analysis...
# Grouping components...
# Running frequency time analysis...
# Analysing trend...
# Calculating time-series autocorrelation...
# running peridogram analysis
#
#                  Breakpoint Model Comparision Results
# ...
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -398.62         True         5.62
# 1                    -410.71         True       4.7515
#
# Min BIC (Bayesian Information Criterion) suggests best model
# Auto Cissa Complete!

# %%
cissa_object_500.figures.get('cissa').get('figure_gap_fill')

# %% [markdown]
# ## convergence = 200

# %%
#create the cissa object
cissa_object_200 = Cissa(t=data_with_gaps['Date'],x=data_with_gaps['Electric power consumption in Spain'])
cissa_object_200.auto_cissa(L = 12*23,
                       K_surrogates = 5, alpha = 0.05,  #settings some parameters for the Monte-Carlo routine
                       test_number = 20, test_repeats=20, #These settings help us to understand the error during gap filling. For 10 repeats we remove 10 known points, gap fill, and calculate the error. On the last run all points are included (none removed) 
                       initial_guess = ['previous', 1.1], #this means we set missing values to the previous good value multiplied by 1.25 
                        max_iter = 1000, #ensuring we have enough iterations to converge
                        convergence = ['value', 200], #convergence value    
                       )
cissa_object_200.figures.get('cissa').get('figure_gap_fill_error')
# Out:
# Checking for censored or nan data...
# RUNNING CISSA!
# Performing monte-carlo significance analysis...
# Grouping components...
# Running frequency time analysis...
# Analysing trend...
# Calculating time-series autocorrelation...
# running peridogram analysis
#
#                  Breakpoint Model Comparision Results
# ...
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -400.79         True       5.7045
# 1                    -414.22         True       4.7797
#
# Min BIC (Bayesian Information Criterion) suggests best model
# Auto Cissa Complete!

# %% [markdown]
# ## convergence = 100

# %%
#create the cissa object
cissa_object_100 = Cissa(t=data_with_gaps['Date'],x=data_with_gaps['Electric power consumption in Spain'])
cissa_object_100.auto_cissa(L = 12*23,
                       K_surrogates = 5, alpha = 0.05,  #settings some parameters for the Monte-Carlo routine
                       test_number = 20, test_repeats=20, #These settings help us to understand the error during gap filling. For 10 repeats we remove 10 known points, gap fill, and calculate the error. On the last run all points are included (none removed) 
                       initial_guess = ['previous', 1.1], #this means we set missing values to the previous good value multiplied by 1.25 
                        max_iter = 1000, #ensuring we have enough iterations to converge
                        convergence = ['value', 100], #convergence value    
                       )
cissa_object_100.figures.get('cissa').get('figure_gap_fill_error')
# Out:
# Checking for censored or nan data...
# RUNNING CISSA!
# Performing monte-carlo significance analysis...
# Grouping components...
# Running frequency time analysis...
# Analysing trend...
# Calculating time-series autocorrelation...
# running peridogram analysis
#
#                  Breakpoint Model Comparision Results
# ...
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -399.92         True       5.7426
# 1                    -414.07         True        4.785
#
# Min BIC (Bayesian Information Criterion) suggests best model
# Auto Cissa Complete!

# %% [markdown]
# ## convergence = 50

# %%
#create the cissa object
cissa_object_50 = Cissa(t=data_with_gaps['Date'],x=data_with_gaps['Electric power consumption in Spain'])
cissa_object_50.auto_cissa(L = 12*23,
                       K_surrogates = 5, alpha = 0.05,  #settings some parameters for the Monte-Carlo routine
                       test_number = 20, test_repeats=20, #These settings help us to understand the error during gap filling. For 10 repeats we remove 10 known points, gap fill, and calculate the error. On the last run all points are included (none removed) 
                       initial_guess = ['previous', 1.1], #this means we set missing values to the previous good value multiplied by 1.25 
                        max_iter = 1000, #ensuring we have enough iterations to converge
                        convergence = ['value', 50], #convergence value    
                       )
cissa_object_50.figures.get('cissa').get('figure_gap_fill_error')
# Out:
# Checking for censored or nan data...
# RUNNING CISSA!
# Performing monte-carlo significance analysis...
# Grouping components...
# Running frequency time analysis...
# Analysing trend...
# Calculating time-series autocorrelation...
# running peridogram analysis
#
#                  Breakpoint Model Comparision Results
# ...
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -398.84         True       5.6106
# 1                     -410.7         True       4.7517
#
# Min BIC (Bayesian Information Criterion) suggests best model
# Auto Cissa Complete!

# %% [markdown]
# ## convergence = 10

# %%
#create the cissa object
cissa_object_10 = Cissa(t=data_with_gaps['Date'],x=data_with_gaps['Electric power consumption in Spain'])
cissa_object_10.auto_cissa(L = 12*23,
                       K_surrogates = 5, alpha = 0.05,  #settings some parameters for the Monte-Carlo routine
                       test_number = 20, test_repeats=20, #These settings help us to understand the error during gap filling. For 10 repeats we remove 10 known points, gap fill, and calculate the error. On the last run all points are included (none removed) 
                       initial_guess = ['previous', 1.1], #this means we set missing values to the previous good value multiplied by 1.25 
                        max_iter = 1000, #ensuring we have enough iterations to converge
                        convergence = ['value', 10], #convergence value    
                       )
cissa_object_10.figures.get('cissa').get('figure_gap_fill_error')
# Out:
# Checking for censored or nan data...
# RUNNING CISSA!
# Performing monte-carlo significance analysis...
# Grouping components...
# Running frequency time analysis...
# Analysing trend...
# Calculating time-series autocorrelation...
# running peridogram analysis
#
#                  Breakpoint Model Comparision Results
# ...
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -398.58         True       5.6216
# 1                    -410.77         True       4.7494
#
# Min BIC (Bayesian Information Criterion) suggests best model
# Auto Cissa Complete!

# %% [markdown]
# ## convergence = 1

# %%
#create the cissa object
cissa_object_1 = Cissa(t=data_with_gaps['Date'],x=data_with_gaps['Electric power consumption in Spain'])
cissa_object_1.auto_cissa(L = 12*23,
                       K_surrogates = 5, alpha = 0.05,  #settings some parameters for the Monte-Carlo routine
                       test_number = 20, test_repeats=20, #These settings help us to understand the error during gap filling. For 10 repeats we remove 10 known points, gap fill, and calculate the error. On the last run all points are included (none removed) 
                       initial_guess = ['previous', 1.1], #this means we set missing values to the previous good value multiplied by 1.25 
                        max_iter = 1000, #ensuring we have enough iterations to converge
                        convergence = ['value', 1], #convergence value    
                       )
cissa_object_1.figures.get('cissa').get('figure_gap_fill_error')
# Out:
# Checking for censored or nan data...
# RUNNING CISSA!
# Performing monte-carlo significance analysis...
# Grouping components...
# Running frequency time analysis...
# Analysing trend...
# Calculating time-series autocorrelation...
# running peridogram analysis
#
#                  Breakpoint Model Comparision Results
# ...
# n_breakpoints            BIC    converged          RSS
# ----------------------------------------------------------------------------------------------------
# 0                    -398.58         True       5.6216
# 1                    -410.77         True       4.7494
#
# Min BIC (Bayesian Information Criterion) suggests best model
# Auto Cissa Complete!

# %%
cissa_object_1000.figures.get('cissa').get('figure_gap_fill')

# %%
cissa_object_500.figures.get('cissa').get('figure_gap_fill')

# %%
cissa_object_100.figures.get('cissa').get('figure_gap_fill')

# %%
cissa_object_50.figures.get('cissa').get('figure_gap_fill')

# %%
cissa_object_10.figures.get('cissa').get('figure_gap_fill')

# %%
cissa_object_1.figures.get('cissa').get('figure_gap_fill')

# %%
print('true: ',data['Electric power consumption in Spain'][100],', imputed: ',cissa_object_1000.x[100],'percentage error = ', 100*(data['Electric power consumption in Spain'][100] - cissa_object_1000.x[100])/data['Electric power consumption in Spain'][100])
print('true: ',data['Electric power consumption in Spain'][200],', imputed: ',cissa_object_1000.x[200],'percentage error = ', 100*(data['Electric power consumption in Spain'][200] - cissa_object_1000.x[200])/data['Electric power consumption in Spain'][200])
print('true: ',data['Electric power consumption in Spain'][300],', imputed: ',cissa_object_1000.x[300],'percentage error = ', 100*(data['Electric power consumption in Spain'][300] - cissa_object_1000.x[300])/data['Electric power consumption in Spain'][300])
print('true: ',data['Electric power consumption in Spain'][400],', imputed: ',cissa_object_1000.x[400],'percentage error = ', 100*(data['Electric power consumption in Spain'][400] - cissa_object_1000.x[400])/data['Electric power consumption in Spain'][400])
print('true: ',data['Electric power consumption in Spain'][500],', imputed: ',cissa_object_1000.x[500],'percentage error = ', 100*(data['Electric power consumption in Spain'][500] - cissa_object_1000.x[500])/data['Electric power consumption in Spain'][500])
# Out:
# true:  8680.2 , imputed:  8341.652262816264 percentage error =  3.9002296857645775
# true:  11537.2 , imputed:  11261.269922132748 percentage error =  2.391655495850407
# true:  17861.48079 , imputed:  17335.657522824415 percentage error =  2.9438951526906787
# true:  20942.10015 , imputed:  20423.92305039371 percentage error =  2.474332067437314
# true:  20808.25338 , imputed:  20530.751441601416 percentage error =  1.3336147601187172

# %%
print('true: ',data['Electric power consumption in Spain'][100],', imputed: ',cissa_object_500.x[100],'percentage error = ', 100*(data['Electric power consumption in Spain'][100] - cissa_object_500.x[100])/data['Electric power consumption in Spain'][100])
print('true: ',data['Electric power consumption in Spain'][200],', imputed: ',cissa_object_500.x[200],'percentage error = ', 100*(data['Electric power consumption in Spain'][200] - cissa_object_500.x[200])/data['Electric power consumption in Spain'][200])
print('true: ',data['Electric power consumption in Spain'][300],', imputed: ',cissa_object_500.x[300],'percentage error = ', 100*(data['Electric power consumption in Spain'][300] - cissa_object_500.x[300])/data['Electric power consumption in Spain'][300])
print('true: ',data['Electric power consumption in Spain'][400],', imputed: ',cissa_object_500.x[400],'percentage error = ', 100*(data['Electric power consumption in Spain'][400] - cissa_object_500.x[400])/data['Electric power consumption in Spain'][400])
print('true: ',data['Electric power consumption in Spain'][500],', imputed: ',cissa_object_500.x[500],'percentage error = ', 100*(data['Electric power consumption in Spain'][500] - cissa_object_500.x[500])/data['Electric power consumption in Spain'][500])
# Out:
# true:  8680.2 , imputed:  8362.120172043502 percentage error =  3.664429713099914
# true:  11537.2 , imputed:  11249.513144442146 percentage error =  2.4935587105870995
# true:  17861.48079 , imputed:  17312.645262272585 percentage error =  3.0727325140628317
# true:  20942.10015 , imputed:  20436.320775610973 percentage error =  2.4151320582287696
# true:  20808.25338 , imputed:  20506.10653879675 percentage error =  1.452052873854654

# %%
print('true: ',data['Electric power consumption in Spain'][100],', imputed: ',cissa_object_100.x[100],'percentage error = ', 100*(data['Electric power consumption in Spain'][100] - cissa_object_100.x[100])/data['Electric power consumption in Spain'][100])
print('true: ',data['Electric power consumption in Spain'][200],', imputed: ',cissa_object_100.x[200],'percentage error = ', 100*(data['Electric power consumption in Spain'][200] - cissa_object_100.x[200])/data['Electric power consumption in Spain'][200])
print('true: ',data['Electric power consumption in Spain'][300],', imputed: ',cissa_object_100.x[300],'percentage error = ', 100*(data['Electric power consumption in Spain'][300] - cissa_object_100.x[300])/data['Electric power consumption in Spain'][300])
print('true: ',data['Electric power consumption in Spain'][400],', imputed: ',cissa_object_100.x[400],'percentage error = ', 100*(data['Electric power consumption in Spain'][400] - cissa_object_100.x[400])/data['Electric power consumption in Spain'][400])
print('true: ',data['Electric power consumption in Spain'][500],', imputed: ',cissa_object_100.x[500],'percentage error = ', 100*(data['Electric power consumption in Spain'][500] - cissa_object_100.x[500])/data['Electric power consumption in Spain'][500])
# Out:
# true:  8680.2 , imputed:  8340.206627920155 percentage error =  3.9168840819318143
# true:  11537.2 , imputed:  11261.630961812873 percentage error =  2.3885261431467613
# true:  17861.48079 , imputed:  17335.47802093736 percentage error =  2.9449001191274755
# true:  20942.10015 , imputed:  20417.97787749014 percentage error =  2.5027206858709423
# true:  20808.25338 , imputed:  20524.982227185254 percentage error =  1.3613403664481172

# %%
print('true: ',data['Electric power consumption in Spain'][100],', imputed: ',cissa_object_1.x[100],'percentage error = ', 100*(data['Electric power consumption in Spain'][100] - cissa_object_1.x[100])/data['Electric power consumption in Spain'][100])
print('true: ',data['Electric power consumption in Spain'][200],', imputed: ',cissa_object_1.x[200],'percentage error = ', 100*(data['Electric power consumption in Spain'][200] - cissa_object_1.x[200])/data['Electric power consumption in Spain'][200])
print('true: ',data['Electric power consumption in Spain'][300],', imputed: ',cissa_object_1.x[300],'percentage error = ', 100*(data['Electric power consumption in Spain'][300] - cissa_object_1.x[300])/data['Electric power consumption in Spain'][300])
print('true: ',data['Electric power consumption in Spain'][400],', imputed: ',cissa_object_1.x[400],'percentage error = ', 100*(data['Electric power consumption in Spain'][400] - cissa_object_1.x[400])/data['Electric power consumption in Spain'][400])
print('true: ',data['Electric power consumption in Spain'][500],', imputed: ',cissa_object_1.x[500],'percentage error = ', 100*(data['Electric power consumption in Spain'][500] - cissa_object_1.x[500])/data['Electric power consumption in Spain'][500])
# Out:
# true:  8680.2 , imputed:  8340.13797288953 percentage error =  3.9176750202814543
# true:  11537.2 , imputed:  11261.673690967824 percentage error =  2.388155783311175
# true:  17861.48079 , imputed:  17335.531175565564 percentage error =  2.94460252550224
# true:  20942.10015 , imputed:  20417.69880914351 percentage error =  2.504053256838664
# true:  20808.25338 , imputed:  20524.711318736478 percentage error =  1.3626422943121657

# %%
import matplotlib.pyplot as plt
# Create the plot
plt.plot([1000,500,200,100,50,10,1], 
         [cissa_object_1000.gap_fill_error_rmse, 
         cissa_object_500.gap_fill_error_rmse,
         cissa_object_200.gap_fill_error_rmse,
         cissa_object_100.gap_fill_error_rmse,
         cissa_object_50.gap_fill_error_rmse,
         cissa_object_10.gap_fill_error_rmse,
         cissa_object_1.gap_fill_error_rmse], 
         marker='o')  # Line plot with circle markers

# Add labels and title
plt.xlabel('Convergence')
plt.ylabel('RMSE')
plt.title('Convergence vs RMSE')

# Show the plot
plt.show()
